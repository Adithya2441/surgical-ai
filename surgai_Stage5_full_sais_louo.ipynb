# %% [markdown]
# ## Stage 5 - full SAIS LOUO

# %% [markdown]
# ### Data folder structure

# %%
import os

for root, dirs, files in os.walk("JIGSAWS"):
    level = root.replace("JIGSAWS", "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    if level < 3:
        for f in files[:3]:
            print(f"    {indent}{f}")
# Out:
# JIGSAWS/
#     .DS_Store
#   Experimental_setup/
#       .DS_Store
#     Knot_Tying/
#         .DS_Store
#       Balanced/
#         GestureClassification/
#           OneTrialOut/
#             25_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             31_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             19_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             18_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             30_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             24_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             32_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             26_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             27_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             33_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             37_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             23_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             22_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             36_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             20_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             34_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             35_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             21_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             1_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             3_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             2_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             6_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             7_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             5_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             4_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             9_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             8_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             10_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             38_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             39_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             11_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             13_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             12_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             16_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             17_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             29_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             15_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             14_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             28_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#           UserOut/
#             1_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             3_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             2_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             6_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             7_Out/
#               itr_44/
# ...
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             7_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             5_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             4_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             8_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#           SuperTrialOut/
#             1_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             3_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             2_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             5_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#             4_Out/
#               itr_44/
#               itr_43/
#               itr_17/
#               itr_28/
#               itr_10/
#               itr_9/
#               itr_26/
#               itr_19/
#               itr_21/
#               itr_7/
#               itr_42/
#               itr_45/
#               itr_6/
#               itr_20/
#               itr_27/
#               itr_1/
#               itr_18/
#               itr_11/
#               itr_8/
#               itr_16/
#               itr_29/
#               itr_34/
#               itr_33/
#               itr_32/
#               itr_35/
#               itr_50/
#               itr_13/
#               itr_14/
#               itr_22/
#               itr_4/
#               itr_3/
#               itr_25/
#               itr_49/
#               itr_40/
#               itr_47/
#               itr_24/
#               itr_2/
#               itr_5/
#               itr_23/
#               itr_15/
#               itr_12/
#               itr_46/
#               itr_41/
#               itr_48/
#               itr_30/
#               itr_37/
#               itr_39/
#               itr_38/
#               itr_36/
#               itr_31/
#       unBalanced/
#         GestureClassification/
#           OneTrialOut/
#             25_Out/
#               itr_1/
#             31_Out/
#               itr_1/
#             19_Out/
#               itr_1/
#             18_Out/
#               itr_1/
#             30_Out/
#               itr_1/
#             24_Out/
#               itr_1/
#             32_Out/
#               itr_1/
#             26_Out/
#               itr_1/
#             27_Out/
#               itr_1/
#             33_Out/
#               itr_1/
#             37_Out/
#               itr_1/
#             23_Out/
#               itr_1/
#             22_Out/
#               itr_1/
#             36_Out/
#               itr_1/
#             20_Out/
#               itr_1/
#             34_Out/
#               itr_1/
#             35_Out/
#               itr_1/
#             21_Out/
#               itr_1/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             6_Out/
#               itr_1/
#             7_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#             9_Out/
#               itr_1/
#             8_Out/
#               itr_1/
#             10_Out/
#               itr_1/
#             38_Out/
#               itr_1/
#             39_Out/
#               itr_1/
#             11_Out/
#               itr_1/
#             13_Out/
#               itr_1/
#             12_Out/
#               itr_1/
#             16_Out/
#               itr_1/
#             17_Out/
#               itr_1/
#             29_Out/
#               itr_1/
#             15_Out/
#               itr_1/
#             14_Out/
#               itr_1/
#             28_Out/
#               itr_1/
#           UserOut/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             6_Out/
#               itr_1/
#             7_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#             8_Out/
#               itr_1/
#           SuperTrialOut/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#         GestureRecognition/
#           OneTrialOut/
#             25_Out/
#               itr_1/
#             31_Out/
#               itr_1/
#             19_Out/
#               itr_1/
#             18_Out/
#               itr_1/
#             30_Out/
#               itr_1/
#             24_Out/
#               itr_1/
#             32_Out/
#               itr_1/
#             26_Out/
#               itr_1/
#             27_Out/
#               itr_1/
#             33_Out/
#               itr_1/
#             37_Out/
#               itr_1/
#             23_Out/
#               itr_1/
#             22_Out/
#               itr_1/
#             36_Out/
#               itr_1/
#             20_Out/
#               itr_1/
#             34_Out/
#               itr_1/
#             35_Out/
#               itr_1/
#             21_Out/
#               itr_1/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             6_Out/
#               itr_1/
#             7_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#             9_Out/
#               itr_1/
#             8_Out/
#               itr_1/
#             10_Out/
#               itr_1/
#             38_Out/
#               itr_1/
#             39_Out/
#               itr_1/
#             11_Out/
#               itr_1/
#             13_Out/
#               itr_1/
#             12_Out/
#               itr_1/
#             16_Out/
#               itr_1/
#             17_Out/
#               itr_1/
#             29_Out/
#               itr_1/
#             15_Out/
#               itr_1/
#             14_Out/
#               itr_1/
#             28_Out/
#               itr_1/
#           UserOut/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             6_Out/
#               itr_1/
#             7_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#             8_Out/
#               itr_1/
#           SuperTrialOut/
#             1_Out/
#               itr_1/
#             3_Out/
#               itr_1/
#             2_Out/
#               itr_1/
#             5_Out/
#               itr_1/
#             4_Out/
#               itr_1/
#   Knot_Tying/
#       .DS_Store
#       meta_file_Knot_Tying.txt
#       readme.txt
#     video/
#         Knot_Tying_B003_capture2.avi
#         Knot_Tying_G001_capture1.avi
#         Knot_Tying_B004_capture2.avi
#     transcriptions/
#         Knot_Tying_C002.txt
#         Knot_Tying_C003.txt
#         Knot_Tying_C001.txt
#     kinematics/
#       AllGestures/
#   Suturing/
#       .DS_Store
#       meta_file_Suturing.txt
#       readme.txt
#     video/
#         Suturing_H005_capture1.avi
#         Suturing_G002_capture2.avi
#         Suturing_G005_capture2.avi
#     transcriptions/
#         Suturing_C001.txt
#         Suturing_C002.txt
#         Suturing_C003.txt
#     kinematics/
#       AllGestures/
#   Needle_Passing/
#       .DS_Store
#       meta_file_Needle_Passing.txt
#       readme.txt
#     video/
#         Needle_Passing_E001_capture2.avi
#         Needle_Passing_H005_capture1.avi
#         Needle_Passing_H002_capture1.avi
#     transcriptions/
#         Needle_Passing_C001.txt
#         Needle_Passing_C003.txt
#         Needle_Passing_C002.txt
#     kinematics/
#       AllGestures/

# %%
print(os.listdir("Cholec80"))
print(os.listdir("JIGSAWS"))
# Out:
# ['.DS_Store', 'cholec80']
# ['.DS_Store', 'Experimental_setup', 'Knot_Tying', 'Suturing', 'Needle_Passing']

# %%
with open("JIGSAWS/Suturing/transcriptions/Suturing_B001.txt") as f:
    print(f.read())
# Out:
# 80 219 G1
# 220 370 G5
# 371 590 G8
# 591 660 G2
# 661 954 G3
# 955 1097 G8
# 1098 1124 G2
# 1125 1401 G3
# 1402 1439 G2
# 1440 1698 G8
# 1699 1783 G2
# 1784 2285 G3
# 2286 2495 G6
# 2496 2679 G4
# 2680 2750 G2
# 2751 2976 G3
# 2977 3155 G6
# 3156 3308 G4
# 3309 3659 G2
# 3660 4011 G3
# 4012 4321 G8
# 4322 4374 G2
# 4375 4704 G3
# 4705 4846 G6
# 4847 4983 G4
# 4984 5059 G2
# 5060 5354 G3
# 5355 5447 G6
# 5448 5635 G11

# %%
videos = os.listdir("JIGSAWS/Suturing/video/")
print(sorted(videos)[:5])
print(f"Total videos: {len(videos)}")
# Out:
# ['Suturing_B001_capture1.avi', 'Suturing_B001_capture2.avi', 'Suturing_B002_capture1.avi', 'Suturing_B002_capture2.avi', 'Suturing_B003_capture1.avi']
# Total videos: 78

# %% [markdown]
# ### Dataloader

# %%
import torch 
from torch.utils.data import Dataset, DataLoader
import av
import numpy as np 
import os
from torchvision import transforms
import random

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# ensures deterministic behavior in multi-head attention
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark     = False

# mapping gestures to numbers
GESTURE_MAP = {
    'G1':0,'G2':1,'G3':2,'G4':3,'G5':4,
    'G6':5,'G8':6,'G9':7,'G10':8,'G11':9
}

# %%
class JIGSAWSClipDataset(Dataset):
    def __init__(self, task='Suturing', split_trials=None, clip_len=8):
        # split_trials is the list of trial names to include like 'B001', 'B002'

        self.clip_len = clip_len
        self.clips = [] # will (store video_path, start, end, label)

        trans_dir = f"JIGSAWS/{task}/transcriptions/"
        video_dir = f"JIGSAWS/{task}/video/"

        # looping through every transcription file - one per video
        for fname in sorted(os.listdir(trans_dir)):
            if not fname.endswith('.txt'):
                continue

            # extract trial name
            trial = fname.replace(f'{task}_', '').replace('.txt', '')

            # test trials skipped
            if split_trials and trial not in split_trials:
                continue
            
            # we use capture 1 camera angle
            video_path = os.path.join(video_dir, f"{task}_{trial}_capture1.avi") 
            if not os.path.exists(video_path):
                continue

            # read transcription file
            with open(os.path.join(trans_dir, fname)) as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 3: continue
                    start, end, gesture = int(parts[0]), int(parts[1]), parts[2]

                    # keeping only gestures we know and long enough to sample 8 frames
                    if gesture in GESTURE_MAP and (end-start)>clip_len:
                        self.clips.append((video_path, start, end, GESTURE_MAP[gesture]))

                
        # transform to match ResNet
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((224, 224), antialias = True),
            transforms.Normalize([0.485,0.456,0.406],
                                [0.229,0.224,0.225]) 
        ])
        print(f"    {task} {split_trials}: {len(self.clips)} gesture clips")

    
    def _load_frames(self, video_path, start, end):
        # pick clip_len frame indices evenly spread across the gesture segment

        frame_ids = set(np.linspace(start, end, self.clip_len, dtype=int).tolist())
        frames = []
        container = av.open(video_path) # open the video file
        for i, frame in enumerate(container.decode(video=0)):
            if i in frame_ids:
                img = frame.to_ndarray(format='rgb24') # converting to RGB numpy array
                frames.append(self.transform(img)) # resize + transform
            if len(frames) == self.clip_len:
                break # stop when we have all frames

        container.close()

        while len(frames) < self.clip_len:
            frames.append(frames[-1]) # pad the last frame if less

        return torch.stack(frames) # stack into (T, C, H, W) tensor

    def __len__(self): return len(self.clips)

    def __getitem__(self,idx):
        video_path, start, end, label = self.clips[idx]
        frames = self._load_frames(video_path, start, end)

        # for stage 2 we return all frames
        return frames, label

# %%
# loading a sample to check

ds = JIGSAWSClipDataset(task="Suturing")
img, label = ds[0]
print(f"Sample shape: {img.shape}, label: {label}, gesture: {list(GESTURE_MAP.keys())[label]}")
# Out:
#     Suturing None: 793 gesture clips
# Sample shape: torch.Size([8, 3, 224, 224]), label: 0, gesture: G1

# %% [markdown]
# ### Train/test split

# %%
# get all trial names from the transciptions folder
all_trials = [f.replace('Suturing_', '').replace('.txt','')
            for f in os.listdir('JIGSAWS/Suturing/transcriptions/')
            if f.endswith('.txt')]
all_trials = sorted(all_trials)
print("All trials:", all_trials)

# first four trials for test rest train
# JIGSAWS uses leave-one-user-out i am doing it in later stages

test_trials = all_trials[:4]
train_trials = all_trials[4:]

print(f"Train: {train_trials}")
print(f"Test: {test_trials}")

#  create dataset objects
train_clip_ds = JIGSAWSClipDataset('Suturing', split_trials=train_trials)
test_clip_ds  = JIGSAWSClipDataset('Suturing', split_trials=test_trials)

# dataloadaer handles batching + shuffling
train_clip_loader = DataLoader(train_clip_ds, batch_size=16, shuffle=True, num_workers=0)
test_clip_loader = DataLoader(test_clip_ds, batch_size=16, shuffle=False, num_workers=0)
print(f"\nTrain batches: {len(train_clip_loader)}, Test batches: {len(test_clip_loader)}")
# Out:
# All trials: ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']
# Train: ['B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']
# Test: ['B001', 'B002', 'B003', 'B004']
#     Suturing ['B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 710 gesture clips
#     Suturing ['B001', 'B002', 'B003', 'B004']: 83 gesture clips
#
# Train batches: 45, Test batches: 6

# %% [markdown]
# ### RAFT for optical flow

# %%
# Recurrent All-Pairs Field Transforms
from torchvision.models.optical_flow import raft_small, Raft_Small_Weights
import torch

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")


# load pretrained RAFT-small
weights = Raft_Small_Weights.DEFAULT
raft = raft_small(weights=weights).to(device).eval()

# freeze raft as we use it only for feature extraction
for param in raft.parameters():
    param.requires_grad = False

print("Raft loaded successfully")
print(f"Device: {device}")
# Out:
# Raft loaded successfully
# Device: mps

# %% [markdown]
# ### Precomputing and caching optical flow for all runs

# %%
import os
import numpy as np
import av
import torch
from torchvision.models.optical_flow import raft_small, Raft_Small_Weights
from torchvision import transforms
from tqdm import tqdm
import time

FLOW_CACHE_DIR = "flow_cache"
os.makedirs(FLOW_CACHE_DIR, exist_ok=True)

# resize to match our RGB pipeline
resize = transforms.Compose([
    transforms.ToTensor(),      # (3, H, W) as expected but in [0, 1] float
    transforms.Resize((224,224), antialias=True)
])

def get_clip_frames(video_path, start, end, clip_len=8):
    # loading the clip frames we need from the gesture seg
    frame_ids = set(np.linspace(start, end, clip_len, dtype=int).tolist())
    frames = []
    container = av.open(video_path)
    for i, frame in enumerate(container.decode(video=0)):
        if i in frame_ids:
            frames.append(frame.to_ndarray(format='rgb24'))
        if len(frames) == clip_len:
            break
    container.close()
    # padding if video ended early
    while len(frames) < clip_len:
        frames.append(frames[-1])
    return frames # list of clip np arr (H, W, 3)

def compute_clip_flow(frames, raft, device):
    # compute flow between consec frames to produce clip_len-1 flow map
    flows = []
    for i in range(len(frames)-1):
        f1 = resize(frames[i]).unsqueeze(0).to(device) * 255.0
        f2 = resize(frames[i+1]).unsqueeze(0).to(device) * 255.0    # both (1, 3, 224, 224)
        with torch.no_grad():
            flow = raft(f1, f2)[-1].squeeze(0).cpu().numpy()    # (2, 224, 224)

        flows.append(flow)
    return np.stack(flows)      # (clip_len-1, 2, 224, 224)


# do for all tasks - generate clip keys and compute flow
tasks = ['Suturing', 'Knot_Tying', 'Needle_Passing']
all_clips = []

for task in tasks:
    trans_dir = f"JIGSAWS/{task}/transcriptions/"
    video_dir = f"JIGSAWS/{task}/video/"
    for fname in sorted(os.listdir(trans_dir)):
        if not fname.endswith('.txt'): 
            continue
        trial = fname.replace(f'{task}_','').replace('.txt', '')
        video_path = os.path.join(video_dir, f"{task}_{trial}_capture1.avi")
        if not os.path.exists(video_path): 
            continue
        with open(os.path.join(trans_dir, fname)) as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 3: 
                    continue
                start, end, gesture = int(parts[0]), int(parts[1]), parts[2]
                if gesture in GESTURE_MAP and (end - start) >= 8:
                    # generate a unique key per clip: task_trial_start_end.npy
                    key = f"{task}_{trial}_{start}_{end}.npy"
                    all_clips.append((video_path, start, end, key))

print(f"Total clips to cache: {len(all_clips)}")

# compute and cache flow
skipped = 0
computed = 0
total_start = time.time()


for video_path, start, end, key in tqdm(all_clips, desc="Caching flow"):
    cache_path = os.path.join(FLOW_CACHE_DIR, key)
    if os.path.exists(cache_path):
        skipped += 1
        continue
    frames = get_clip_frames(video_path, start, end, clip_len=8)
    flow = compute_clip_flow(frames, raft, device)
    np.save(cache_path, flow)
    computed += 1

total_time = time.time() - total_start
print(f"\nComputed: {computed}, Skipped (cached): {skipped}")
print(f"Total time: {total_time/60:.1f} min")

# verify cache
cache_files = sorted(os.listdir(FLOW_CACHE_DIR))
sample      = np.load(os.path.join(FLOW_CACHE_DIR, cache_files[0]))
total_mb    = sum(os.path.getsize(os.path.join(FLOW_CACHE_DIR, f)) for f in cache_files) / 1e6

print(f"\nCached flow files: {len(cache_files)}")
print(f"Sample: {cache_files[0]}")
print(f"Shape:  {sample.shape}  (clip_len-1, 2, H, W)")
print(f"Min: {sample.min():.3f}, Max: {sample.max():.3f}")
print(f"Total cache size: {total_mb:.1f} MB")
# Out:
# Total clips to cache: 1387
# Caching flow: 100%|██████████| 1387/1387 [00:00<00:00, 394273.10it/s]
# Computed: 0, Skipped (cached): 1387
# Total time: 0.0 min
#
# Cached flow files: 1387
# Sample: Knot_Tying_B001_1627_1735.npy
# Shape:  (7, 2, 224, 224)  (clip_len-1, 2, H, W)
# Min: -562.270, Max: 109.659
# Total cache size: 3897.4 MB

# %% [markdown]
# ### Two stream dataset (RGB + flow)

# %%
FLOW_CACHE_DIR = "flow_cache"

class JIGSAWSClipDatasetWithFlow(Dataset):
    def __init__(self, task='Suturing', split_trials=None, clip_len=8):
        self.clip_len = clip_len
        self.clips = []  # (video_path, start, end, label, cache_key)

        trans_dir = f"JIGSAWS/{task}/transcriptions/"
        video_dir = f"JIGSAWS/{task}/video/"

        for fname in sorted(os.listdir(trans_dir)):
            if not fname.endswith('.txt'):
                continue
            trial = fname.replace(f'{task}_', '').replace(".txt", '')
            if split_trials and trial not in split_trials:
                continue

            video_path = os.path.join(video_dir, f"{task}_{trial}_capture1.avi")

            if not os.path.exists(video_path):
                continue

            with open(os.path.join(trans_dir, fname)) as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 3:
                        continue
                    start, end, gesture = int(parts[0]), int(parts[1]), parts[2]
                    if gesture in GESTURE_MAP and (end - start) >= clip_len:
                        key = f"{task}_{trial}_{start}_{end}.npy"
                        self.clips.append((video_path, start, end, GESTURE_MAP[gesture], key))

        
        self.rgb_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((224, 224), antialias=True),
            transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
        ])

        # flow normalization - zero mean, unit std across typical flow magnitudes
        self.flow_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((224, 224), antialias=True),
        ])

        print(f"{task} {split_trials}: {len(self.clips)} clips")

    def _load_rgb(self, video_path, start, end):
        # load the RGB frames from gesture seg
    
        frame_ids = set(np.linspace(start, end, self.clip_len, dtype=int).tolist())
        frames = []
        container = av.open(video_path)
        for i, frame in enumerate(container.decode(video=0)):
            if i in frame_ids:
                img = frame.to_ndarray(format='rgb24')
                frames.append(self.rgb_transform(img))
            if len(frames) == self.clip_len:
                break
        container.close()
        while len(frames) < self.clip_len:
            frames.append(frames[-1])
        return torch.stack(frames)  # (T, 3, 224, 224)
    
    def _load_flow(self, key):
        # load precomputed flow from cache (T - 1, 2, 224, 224)

        cache_path = os.path.join(FLOW_CACHE_DIR, key)
        flow = np.load(cache_path)  # (7, 2, 224, 224)
        flow = torch.tensor(flow, dtype=torch.float32)

        # normalize flow to roughly [-1, 1] range
        flow = flow/(flow.abs().max() + 1e-6)
        return flow # (T-1, 2, 224, 224)
    
    def __len__(self):
        return len(self.clips)
    
    def __getitem__(self, idx):
        video_path, start, end, label, key = self.clips[idx]
        rgb  = self._load_rgb(video_path, start, end)   # (8, 3, 224, 224)
        flow = self._load_flow(key)       # (7, 2, 224, 224)

        # pad flow to match rgb length by repeating last flow map

        last = flow[-1:].clone()
        flow = torch.cat([flow, last], dim=0)     # (8, 2, 224, 224)
        return rgb, flow, label
    


# sanity check
ds_check = JIGSAWSClipDatasetWithFlow('Suturing')
rgb, flow, label = ds_check[0]
print(f"RGB shape:  {rgb.shape}")
print(f"Flow shape: {flow.shape}")
print(f"Label: {label}, Gesture: {list(GESTURE_MAP.keys())[label]}")
# Out:
# Suturing None: 793 clips
# RGB shape:  torch.Size([8, 3, 224, 224])
# Flow shape: torch.Size([8, 2, 224, 224])
# Label: 0, Gesture: G1

# %% [markdown]
# ### SAIS Model

# %%
import timm
import torch.nn as nn
import torch.nn.functional as F

class SAISModel(nn.Module):
    def __init__(self, n_classes = 10, clip_len=8, feat_dim=384,
                 proj_dim=256, n_heads=6, n_layers=4, dropout=0.1):
        super().__init__()
        self.clip_len = clip_len

        # RGB stream - frozen DINO-ViT-Small
        self.rgb_vit = timm.create_model(
            'vit_small_patch16_224.dino',
            pretrained=True, num_classes=0
        )
        for p in self.rgb_vit.parameters():
            p.requires_grad = False

        # FLOW stream - frozen DINO-ViT-Small
        # flow has 2 channels not 3 so we poject 2ch -> 3ch with a small learned conv before ViT
        self.flow_proj = nn.Conv2d(2, 3, kernel_size=1) # learned projection
        self.flow_vit = timm.create_model(
            'vit_small_patch16_224.dino',
            pretrained=True, num_classes=0
        )
        for p in self.flow_vit.parameters():
            p.requires_grad = False


        # RGB transformer
        self.rgb_cls   = nn.Parameter(torch.randn(1, 1, feat_dim))
        self.rgb_pos   = nn.Parameter(torch.randn(1, clip_len + 1, feat_dim))
        rgb_layer      = nn.TransformerEncoderLayer(
            d_model=feat_dim, nhead=n_heads,
            dim_feedforward=feat_dim * 4,
            dropout=dropout, batch_first=True
        )
        self.rgb_transformer = nn.TransformerEncoder(rgb_layer, n_layers)
        self.rgb_norm        = nn.LayerNorm(feat_dim)

        # Flow transformer - separate weights, same architecture
        self.flow_cls  = nn.Parameter(torch.randn(1, 1, feat_dim))
        self.flow_pos  = nn.Parameter(torch.randn(1, clip_len + 1, feat_dim))
        flow_layer     = nn.TransformerEncoderLayer(
            d_model=feat_dim, nhead=n_heads,
            dim_feedforward=feat_dim * 4,
            dropout=dropout, batch_first=True
        )
        self.flow_transformer = nn.TransformerEncoder(flow_layer, n_layers)
        self.flow_norm        = nn.LayerNorm(feat_dim)

        # proj head
        self.proj_head = nn.Sequential(
            nn.Linear(feat_dim * 2, proj_dim),
            nn.ReLU(),
            nn.Linear(proj_dim, proj_dim)
        )

        # prototype classifier
        self.prototypes = nn.Parameter(torch.randn(n_classes, proj_dim))
        self.temperature = 0.07

    def encode_stream(self, x, vit):
        # encode T frames through frozen Vit independently
        # x:   (B, T, C, H, W)
        # out: (B, T, feat_dim)
        B, T, C, H, W = x.shape
        x = x.view(B*T, C, H, W)
        with torch.no_grad():
            x = vit(x)          # (B*T, feat_dim
        return x.view(B, T, -1)     # (B, T, feat_dim)
    

    def temporal_encode(self, x, cls_token, pos_embed, transformer, norm):
        # run temporal transformeer on frame features
        # x:   (B, T, feat_dim)
        # out: (B, feat_dim) — CLS token

        B = x.shape[0]
        cls = cls_token.expand(B, -1, -1)
        x   = torch.cat([cls, x], dim=1)   # (B, T+1, feat_dim)
        x   = x + pos_embed
        x   = transformer(x)
        x   = norm(x)
        return x[:, 0, :]     # cls token (B, feat_dim)
    
    def forward(self, rgb, flow, labels=None):
        # rgb:    (B, T, 3, H, W)
        # flow:   (B, T, 2, H, W)
        # labels: (B,) during training, None at inference
        

        B, T, _, H, W = flow.shape

        # proj the 2ch to 3ch
        flow_3ch = self.flow_proj(flow.view(B*T, 2, H, W)) # (B*T, 3, H, W)
        flow_3ch = flow_3ch.view(B, T, 3, H, W)

        # extract rgb and flow feat
        rgb_feat = self.encode_stream(rgb, self.rgb_vit) # (B, T, 384)
        flow_feat = self.encode_stream(flow_3ch, self.flow_vit) # (B, T, 384)

        # separate temporal transformers per stream
        h_rgb  = self.temporal_encode(
            rgb_feat,  self.rgb_cls,  self.rgb_pos,
            self.rgb_transformer,  self.rgb_norm
        )  # (B, 384)
        h_flow = self.temporal_encode(
            flow_feat, self.flow_cls, self.flow_pos,
            self.flow_transformer, self.flow_norm
        )  # (B, 384)

        # fuse by ele wise addn
        fused = torch.cat([h_rgb, h_flow], dim=-1)  # (B, 768)

        # proj + proto classify
        h = self.proj_head(fused)       # (B, proj_dim)
        h_norm = F.normalize(h, dim=1)
        p_norm = F.normalize(self.prototypes, dim=1)
        logits = h_norm @ p_norm.T / self.temperature

        if labels is not None:
            loss = F.cross_entropy(logits, labels)
            return loss, logits
        return logits
    
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
torch.manual_seed(SEED)
model4 = SAISModel(n_classes=10, clip_len=8).to(device)

trainable4 = [p for p in model4.parameters() if p.requires_grad]
optimizer4 = torch.optim.Adam(trainable4, lr=1e-4, weight_decay=1e-4)
scheduler4 = torch.optim.lr_scheduler.StepLR(optimizer4, step_size=5, gamma=0.5)

total = sum(p.numel() for p in model4.parameters() if p.requires_grad)
print(f"Trainable params: {total:,}  (both ViTs frozen)")
print(f"Device: {device}")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Trainable params: 14,470,153  (both ViTs frozen)
# Device: mps

# %% [markdown]
# ### Stage 5a - LOUO folder builder

# %%
# Leave one user out evaluation
# JIGSAWS users: B, C, D, E, F, G, H, I
# each fold holds out all trials from one user entirely


def get_louo_folds():
    # returns list of (user, train_trials, test_trials) tuples - one fold per user

    all_trials = [f.replace('Suturing_','').replace('.txt','')
                  for f in os.listdir("JIGSAWS/Suturing/transcriptions/")
                  if f.endswith('.txt')]
    all_trials = sorted(all_trials)

    # extract unique users - first letter of trial name
    users = sorted(set(t[0] for t in all_trials))
    print(f'Users: {users}')
    print(f"Total trials: {len(all_trials)}")

    folds = []
    for user in users:
        test_trials = [t for t in all_trials if t.startswith(user)]
        train_trials = [t for t in all_trials if not t.startswith(user)]
        folds.append((user, train_trials, test_trials))
        print(f"  User {user}: test={test_trials}, train_size={len(train_trials)}")

    return folds

folds = get_louo_folds()
print(f"\nTotal folds: {len(folds)}")
# Out:
# Users: ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# Total trials: 39
#   User B: test=['B001', 'B002', 'B003', 'B004', 'B005'], train_size=34
#   User C: test=['C001', 'C002', 'C003', 'C004', 'C005'], train_size=34
#   User D: test=['D001', 'D002', 'D003', 'D004', 'D005'], train_size=34
#   User E: test=['E001', 'E002', 'E003', 'E004', 'E005'], train_size=34
#   User F: test=['F001', 'F002', 'F003', 'F004', 'F005'], train_size=34
#   User G: test=['G001', 'G002', 'G003', 'G004', 'G005'], train_size=34
#   User H: test=['H001', 'H003', 'H004', 'H005'], train_size=35
#   User I: test=['I001', 'I002', 'I003', 'I004', 'I005'], train_size=34
#
# Total folds: 8

# %% [markdown]
# ### Single fold training function

# %%
from sklearn.metrics import f1_score, precision_score
import time

def train_one_fold(user, train_trials, test_trials, task='Suturing',
                   n_epochs=15, batch_size=8, use_flow=True):
    
    print(f"\n{'='*50}")
    print(f"Fold: hold out User {user} | test={test_trials}")
    print(f"{'='*50}")

    # build datasets
    if use_flow:
        train_ds = JIGSAWSClipDatasetWithFlow(task, split_trials=train_trials)
        test_ds  = JIGSAWSClipDatasetWithFlow(task, split_trials=test_trials)
    else:
        train_ds = JIGSAWSClipDataset(task, split_trials=train_trials)
        test_ds  = JIGSAWSClipDataset(task, split_trials=test_trials)

    if len(test_ds) == 0:
        print(f"  Skipping — no test clips for user {user}")
        return None, None

    train_loader = DataLoader(train_ds, batch_size=batch_size,
                              shuffle=True,  num_workers=0)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size,
                              shuffle=False, num_workers=0)

    print(f"  Train: {len(train_ds)} clips | Test: {len(test_ds)} clips")

    # fresh model per fold — critical for LOUO
    torch.manual_seed(SEED)
    model = SAISModel(n_classes=10, clip_len=8).to(device)
    trainable = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(trainable, lr=1e-4, weight_decay=1e-4)
    # cosine annealing — smoother than step decay
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=n_epochs, eta_min=1e-6
    )

    best_f1 = 0
    best_ppv = 0

    for epoch in range(1, n_epochs + 1):
        t0 = time.time()

        # train
        model.train()
        tr_preds, tr_labels_list = [], []
        for batch in train_loader:
            if use_flow:
                rgb, flow, labels = batch
                rgb, flow, labels = rgb.to(device), flow.to(device), labels.to(device)
                loss, logits = model(rgb, flow, labels=labels)
            else:
                rgb, labels = batch
                rgb, labels = rgb.to(device), labels.to(device)
                loss, logits = model(rgb, labels=labels)

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(trainable, max_norm=1.0)
            optimizer.step()

            tr_preds.extend(logits.argmax(1).cpu().numpy())
            tr_labels_list.extend(labels.cpu().numpy())
        scheduler.step()
        tr_f1 = f1_score(tr_labels_list, tr_preds, average='macro', zero_division=0)
        tr_p  = precision_score(tr_labels_list, tr_preds, average='macro', zero_division=0)

        # eval
        model.eval()
        te_preds, te_labels_list = [], []
        with torch.no_grad():
            for batch in test_loader:
                if use_flow:
                    rgb, flow, labels = batch
                    rgb, flow, labels = rgb.to(device), flow.to(device), labels.to(device)
                    logits = model(rgb, flow)
                else:
                    rgb, labels = batch
                    rgb, labels = rgb.to(device), labels.to(device)
                    logits = model(rgb)

                te_preds.extend(logits.argmax(1).cpu().numpy())
                te_labels_list.extend(labels.cpu().numpy())

        te_f1 = f1_score(te_labels_list, te_preds, average='macro', zero_division=0)
        te_p  = precision_score(te_labels_list, te_preds, average='macro', zero_division=0)


        if te_f1 > best_f1:
            best_f1 = te_f1
            best_ppv = te_p

        print(f"  Epoch {epoch:2d} | Train F1: {tr_f1:.3f} Train PPV: {tr_p:.3f} | "
              f"Test F1: {te_f1:.3f} Test PPV: {te_p:.3f} | {time.time()-t0:.1f}s")

    print(f"  Best F1: {best_f1:.3f} | Best PPV: {best_ppv:.3f}")
    return best_f1, best_ppv

# %% [markdown]
# ### Run training for suturing

# %%
print("Stage 5a — Leave-One-User-Out Evaluation")
print("Task: Suturing | Two-stream SAIS (RGB + Flow)")
print("="*50)

louo_results = {}

for user, train_trials, test_trials in folds:
    f1, ppv = train_one_fold(user, train_trials, test_trials,
                              task='Suturing', n_epochs=15,
                              batch_size=8, use_flow=True)
    if f1 is not None:
        louo_results[user] = (f1, ppv)

print("\n" + "="*55)
print("STAGE 5a LOUO RESULTS — Suturing")
for user, (f1, ppv) in louo_results.items():
    print(f"  User {user}: F1 = {f1:.3f} | PPV = {ppv:.3f}")

mean_f1  = sum(v[0] for v in louo_results.values()) / len(louo_results)
mean_ppv = sum(v[1] for v in louo_results.values()) / len(louo_results)
print(f"\n  Mean F1:  {mean_f1:.3f}")
print(f"  Mean PPV: {mean_ppv:.3f}")
print(f"  SAIS PPV: ~0.875")
# Out:
# Stage 5a — Leave-One-User-Out Evaluation
# Task: Suturing | Two-stream SAIS (RGB + Flow)
# ==================================================
#
# ==================================================
# Fold: hold out User B | test=['B001', 'B002', 'B003', 'B004', 'B005']
# ==================================================
# Suturing ['C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 691 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005']: 102 clips
#   Train: 691 clips | Test: 102 clips
#   Epoch  1 | Train F1: 0.263 | Test F1: 0.475 | 134.3s
#   Epoch  2 | Train F1: 0.607 | Test F1: 0.697 | 131.5s
#   Epoch  3 | Train F1: 0.749 | Test F1: 0.728 | 132.5s
#   Epoch  4 | Train F1: 0.782 | Test F1: 0.696 | 136.0s
#   Epoch  5 | Train F1: 0.827 | Test F1: 0.748 | 135.3s
#   Epoch  6 | Train F1: 0.864 | Test F1: 0.819 | 131.0s
#   Epoch  7 | Train F1: 0.873 | Test F1: 0.819 | 127.7s
#   Epoch  8 | Train F1: 0.923 | Test F1: 0.762 | 127.4s
#   Epoch  9 | Train F1: 0.926 | Test F1: 0.799 | 127.5s
#   Epoch 10 | Train F1: 0.984 | Test F1: 0.808 | 128.2s
#   Epoch 11 | Train F1: 0.993 | Test F1: 0.801 | 133.5s
#   Epoch 12 | Train F1: 0.998 | Test F1: 0.799 | 133.6s
#   Epoch 13 | Train F1: 0.998 | Test F1: 0.799 | 130.5s
#   Epoch 14 | Train F1: 0.998 | Test F1: 0.819 | 129.0s
#   Epoch 15 | Train F1: 0.998 | Test F1: 0.801 | 130.8s
#   Best F1 for User B: 0.819
#
# ==================================================
# Fold: hold out User C | test=['C001', 'C002', 'C003', 'C004', 'C005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 697 clips
# Suturing ['C001', 'C002', 'C003', 'C004', 'C005']: 96 clips
#   Train: 697 clips | Test: 96 clips
#   Epoch  1 | Train F1: 0.217 | Test F1: 0.470 | 135.1s
#   Epoch  2 | Train F1: 0.574 | Test F1: 0.576 | 133.5s
#   Epoch  3 | Train F1: 0.725 | Test F1: 0.865 | 130.6s
#   Epoch  4 | Train F1: 0.780 | Test F1: 0.669 | 132.0s
#   Epoch  5 | Train F1: 0.806 | Test F1: 0.813 | 127.6s
#   Epoch  6 | Train F1: 0.826 | Test F1: 0.867 | 133.2s
#   Epoch  7 | Train F1: 0.864 | Test F1: 0.923 | 133.5s
#   Epoch  8 | Train F1: 0.945 | Test F1: 0.823 | 131.3s
#   Epoch  9 | Train F1: 0.959 | Test F1: 0.855 | 128.0s
#   Epoch 10 | Train F1: 0.969 | Test F1: 0.818 | 130.9s
#   Epoch 11 | Train F1: 0.996 | Test F1: 0.845 | 129.4s
#   Epoch 12 | Train F1: 0.994 | Test F1: 0.829 | 132.5s
#   Epoch 13 | Train F1: 0.996 | Test F1: 0.842 | 135.0s
#   Epoch 14 | Train F1: 0.996 | Test F1: 0.817 | 134.8s
#   Epoch 15 | Train F1: 0.998 | Test F1: 0.817 | 133.2s
#   Best F1 for User C: 0.923
#
# ==================================================
# Fold: hold out User D | test=['D001', 'D002', 'D003', 'D004', 'D005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 679 clips
# Suturing ['D001', 'D002', 'D003', 'D004', 'D005']: 114 clips
#   Train: 679 clips | Test: 114 clips
#   Epoch  1 | Train F1: 0.242 | Test F1: 0.298 | 132.7s
#   Epoch  2 | Train F1: 0.606 | Test F1: 0.577 | 128.7s
#   Epoch  3 | Train F1: 0.696 | Test F1: 0.576 | 130.1s
#   Epoch  4 | Train F1: 0.725 | Test F1: 0.489 | 130.3s
#   Epoch  5 | Train F1: 0.759 | Test F1: 0.595 | 132.1s
#   Epoch  6 | Train F1: 0.769 | Test F1: 0.558 | 129.9s
#   Epoch  7 | Train F1: 0.853 | Test F1: 0.618 | 126.6s
#   Epoch  8 | Train F1: 0.926 | Test F1: 0.593 | 125.7s
#   Epoch  9 | Train F1: 0.920 | Test F1: 0.624 | 128.6s
#   Epoch 10 | Train F1: 0.996 | Test F1: 0.649 | 127.1s
#   Epoch 11 | Train F1: 0.999 | Test F1: 0.547 | 125.4s
#   Epoch 12 | Train F1: 0.999 | Test F1: 0.622 | 125.2s
#   Epoch 13 | Train F1: 0.999 | Test F1: 0.576 | 125.5s
#   Epoch 14 | Train F1: 0.999 | Test F1: 0.639 | 125.5s
#   Epoch 15 | Train F1: 0.999 | Test F1: 0.639 | 125.7s
#   Best F1 for User D: 0.649
#
# ==================================================
# Fold: hold out User E | test=['E001', 'E002', 'E003', 'E004', 'E005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 701 clips
# Suturing ['E001', 'E002', 'E003', 'E004', 'E005']: 92 clips
#   Train: 701 clips | Test: 92 clips
#   Epoch  1 | Train F1: 0.286 | Test F1: 0.396 | 128.6s
#   Epoch  2 | Train F1: 0.667 | Test F1: 0.611 | 131.8s
#   Epoch  3 | Train F1: 0.735 | Test F1: 0.534 | 200.9s
#   Epoch  4 | Train F1: 0.801 | Test F1: 0.543 | 132.6s
#   Epoch  5 | Train F1: 0.817 | Test F1: 0.619 | 130.5s
#   Epoch  6 | Train F1: 0.855 | Test F1: 0.556 | 130.8s
#   Epoch  7 | Train F1: 0.862 | Test F1: 0.627 | 132.2s
#   Epoch  8 | Train F1: 0.870 | Test F1: 0.718 | 133.4s
#   Epoch  9 | Train F1: 0.974 | Test F1: 0.685 | 133.3s
#   Epoch 10 | Train F1: 0.975 | Test F1: 0.666 | 132.0s
#   Epoch 11 | Train F1: 0.997 | Test F1: 0.685 | 132.1s
#   Epoch 12 | Train F1: 0.996 | Test F1: 0.665 | 132.4s
#   Epoch 13 | Train F1: 0.999 | Test F1: 0.665 | 132.4s
#   Epoch 14 | Train F1: 1.000 | Test F1: 0.692 | 132.6s
#   Epoch 15 | Train F1: 1.000 | Test F1: 0.686 | 132.2s
#   Best F1 for User E: 0.718
#
# ==================================================
# Fold: hold out User F | test=['F001', 'F002', 'F003', 'F004', 'F005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 703 clips
# Suturing ['F001', 'F002', 'F003', 'F004', 'F005']: 90 clips
#   Train: 703 clips | Test: 90 clips
#   Epoch  1 | Train F1: 0.182 | Test F1: 0.430 | 132.4s
#   Epoch  2 | Train F1: 0.626 | Test F1: 0.685 | 132.5s
#   Epoch  3 | Train F1: 0.698 | Test F1: 0.849 | 132.5s
#   Epoch  4 | Train F1: 0.776 | Test F1: 0.698 | 132.3s
#   Epoch  5 | Train F1: 0.819 | Test F1: 0.741 | 132.5s
#   Epoch  6 | Train F1: 0.856 | Test F1: 0.825 | 132.4s
#   Epoch  7 | Train F1: 0.866 | Test F1: 0.721 | 132.3s
#   Epoch  8 | Train F1: 0.940 | Test F1: 0.791 | 131.8s
#   Epoch  9 | Train F1: 0.945 | Test F1: 0.798 | 131.7s
#   Epoch 10 | Train F1: 0.982 | Test F1: 0.803 | 126.8s
#   Epoch 11 | Train F1: 0.978 | Test F1: 0.819 | 127.2s
#   Epoch 12 | Train F1: 0.997 | Test F1: 0.819 | 128.7s
#   Epoch 13 | Train F1: 0.984 | Test F1: 0.819 | 132.1s
#   Epoch 14 | Train F1: 0.999 | Test F1: 0.819 | 128.8s
#   Epoch 15 | Train F1: 0.999 | Test F1: 0.819 | 128.8s
#   Best F1 for User F: 0.849
#
# ==================================================
# Fold: hold out User G | test=['G001', 'G002', 'G003', 'G004', 'G005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 677 clips
# Suturing ['G001', 'G002', 'G003', 'G004', 'G005']: 116 clips
#   Train: 677 clips | Test: 116 clips
#   Epoch  1 | Train F1: 0.311 | Test F1: 0.313 | 127.7s
#   Epoch  2 | Train F1: 0.672 | Test F1: 0.294 | 127.3s
#   Epoch  3 | Train F1: 0.783 | Test F1: 0.312 | 126.4s
#   Epoch  4 | Train F1: 0.821 | Test F1: 0.492 | 126.3s
#   Epoch  5 | Train F1: 0.847 | Test F1: 0.364 | 126.2s
#   Epoch  6 | Train F1: 0.875 | Test F1: 0.550 | 126.4s
#   Epoch  7 | Train F1: 0.961 | Test F1: 0.531 | 127.3s
#   Epoch  8 | Train F1: 0.972 | Test F1: 0.537 | 126.4s
#   Epoch  9 | Train F1: 0.975 | Test F1: 0.580 | 126.2s
#   Epoch 10 | Train F1: 0.995 | Test F1: 0.568 | 126.1s
#   Epoch 11 | Train F1: 0.998 | Test F1: 0.574 | 126.1s
#   Epoch 12 | Train F1: 0.998 | Test F1: 0.576 | 126.1s
#   Epoch 13 | Train F1: 0.978 | Test F1: 0.548 | 126.4s
#   Epoch 14 | Train F1: 0.998 | Test F1: 0.567 | 126.3s
#   Epoch 15 | Train F1: 1.000 | Test F1: 0.567 | 126.5s
#   Best F1 for User G: 0.580
#
# ==================================================
# Fold: hold out User H | test=['H001', 'H003', 'H004', 'H005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'I001', 'I002', 'I003', 'I004', 'I005']: 707 clips
# Suturing ['H001', 'H003', 'H004', 'H005']: 86 clips
#   Train: 707 clips | Test: 86 clips
#   Epoch  1 | Train F1: 0.167 | Test F1: 0.346 | 126.7s
#   Epoch  2 | Train F1: 0.602 | Test F1: 0.628 | 126.4s
#   Epoch  3 | Train F1: 0.763 | Test F1: 0.613 | 126.3s
#   Epoch  4 | Train F1: 0.808 | Test F1: 0.703 | 126.6s
#   Epoch  5 | Train F1: 0.822 | Test F1: 0.659 | 126.4s
#   Epoch  6 | Train F1: 0.865 | Test F1: 0.599 | 126.4s
#   Epoch  7 | Train F1: 0.881 | Test F1: 0.608 | 126.5s
#   Epoch  8 | Train F1: 0.953 | Test F1: 0.648 | 126.4s
#   Epoch  9 | Train F1: 0.952 | Test F1: 0.614 | 126.4s
#   Epoch 10 | Train F1: 0.993 | Test F1: 0.650 | 126.3s
#   Epoch 11 | Train F1: 0.996 | Test F1: 0.639 | 126.7s
#   Epoch 12 | Train F1: 0.999 | Test F1: 0.650 | 126.4s
#   Epoch 13 | Train F1: 0.999 | Test F1: 0.650 | 126.2s
#   Epoch 14 | Train F1: 0.999 | Test F1: 0.644 | 126.4s
#   Epoch 15 | Train F1: 0.999 | Test F1: 0.644 | 126.3s
#   Best F1 for User H: 0.703
#
# ==================================================
# Fold: hold out User I | test=['I001', 'I002', 'I003', 'I004', 'I005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005']: 696 clips
# Suturing ['I001', 'I002', 'I003', 'I004', 'I005']: 97 clips
#   Train: 696 clips | Test: 97 clips
#   Epoch  1 | Train F1: 0.267 | Test F1: 0.545 | 126.7s
#   Epoch  2 | Train F1: 0.569 | Test F1: 0.730 | 126.2s
#   Epoch  3 | Train F1: 0.746 | Test F1: 0.657 | 126.2s
#   Epoch  4 | Train F1: 0.795 | Test F1: 0.740 | 126.5s
#   Epoch  5 | Train F1: 0.827 | Test F1: 0.820 | 126.4s
#   Epoch  6 | Train F1: 0.849 | Test F1: 0.798 | 126.4s
#   Epoch  7 | Train F1: 0.922 | Test F1: 0.797 | 125.9s
#   Epoch  8 | Train F1: 0.934 | Test F1: 0.720 | 125.8s
#   Epoch  9 | Train F1: 0.971 | Test F1: 0.786 | 125.7s
#   Epoch 10 | Train F1: 0.977 | Test F1: 0.799 | 126.1s
#   Epoch 11 | Train F1: 0.975 | Test F1: 0.831 | 125.5s
#   Epoch 12 | Train F1: 0.998 | Test F1: 0.831 | 125.5s
#   Epoch 13 | Train F1: 0.998 | Test F1: 0.831 | 125.7s
#   Epoch 14 | Train F1: 0.998 | Test F1: 0.831 | 126.2s
#   Epoch 15 | Train F1: 0.998 | Test F1: 0.831 | 126.1s
#   Best F1 for User I: 0.831
#
# ==================================================
# STAGE 5a LOUO RESULTS — Suturing
#   User B: F1 = 0.819
#   User C: F1 = 0.923
#   User D: F1 = 0.649
#   User E: F1 = 0.718
#   User F: F1 = 0.849
#   User G: F1 = 0.580
#   User H: F1 = 0.703
#   User I: F1 = 0.831
#
#   Mean LOUO F1: 0.759
#   SAIS paper reports: ~0.875 PPV (different metric but comparable)

# %% [markdown]
# ### Stage 5b - TTA + Clip Length 16

# %%
# run inference 3 times with diff frame offsets, avg preds
# exactly as in SAIS paper

def predict_with_tta(model, video_path, start, end, 
                     flow_key, device, n_offsets=3):
    # run inference n_offsets times with different frame sampling
    # avg the sofmax prob giving more stabel preds

    model.eval()
    rgb_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((224, 224), antialias=True),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
    ])

    all_probs = []
    clip_len = 8
    seg_len = end - start

    for offset_idx in range(n_offsets):
        # shift by a small offset each time

        offset = int(offset_idx * seg_len / (n_offsets * 4))
        adj_start = min(start + offset, end - clip_len)

        frame_ids = set(np.linspace(adj_start, end, 
                                    clip_len, dtype=int).tolist())
        frames = []
        container = av.open(video_path)
        for i, frame in enumerate(container.decode(video=0)):
            if i in frame_ids:
                img = frame.to_ndarray(format='rgb24')
                frames.append(rgb_transform(img))
            if len(frames) == clip_len:
                break
        container.close()
        while len(frames) < clip_len:
            frames.append(frames[-1])

        rgb  = torch.stack(frames).unsqueeze(0).to(device)  # (1,T,3,H,W)
        flow = np.load(os.path.join(FLOW_CACHE_DIR, flow_key))
        flow = torch.tensor(flow, dtype=torch.float32)
        flow = flow / (flow.abs().max() + 1e-6)
        last = flow[-1:].clone()
        flow = torch.cat([flow, last], dim=0).unsqueeze(0).to(device)

        with torch.no_grad():
            logits = model(rgb, flow)
            probs = torch.softmax(logits, dim=-1)
            all_probs.append(probs)

    # avg probs across offsets
    avg_probs = torch.stack(all_probs).mean(0)
    return avg_probs.argmax(1).item()

# %%
# eval best LOUO model with TTA
print("Stage 5b — Test Time Augmentation")
print("="*50)
print("Re-evaluating each fold with 3-offset TTA")
print("="*50)

tta_results = {}

for user, train_trials, test_trials in folds:
    print(f"\n{'='*50}")
    print(f"Fold: hold out User {user} | test={test_trials}")
    print(f"{'='*50}")

    # rebuild test dataset for this fold
    test_ds = JIGSAWSClipDatasetWithFlow('Suturing', split_trials=test_trials)
    if len(test_ds) == 0:
        continue

    # retrain fold model
    train_ds = JIGSAWSClipDatasetWithFlow('Suturing', split_trials=train_trials)
    train_loader = DataLoader(train_ds, batch_size=8, shuffle=True, num_workers=0)

    print(f"  Train: {len(train_ds)} clips | Test: {len(test_ds)} clips")

    torch.manual_seed(SEED)
    model_tta = SAISModel(n_classes=10, clip_len=8).to(device)
    trainable_t = [p for p in model_tta.parameters() if p.requires_grad]
    optimizer_t = torch.optim.Adam(trainable_t, lr=1e-4, weight_decay=1e-4)
    scheduler_t = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer_t, T_max=15, eta_min=1e-6
    )

    # train
    for epoch in range(1, 16):
        t0 = time.time()
        model_tta.train()
        tr_preds, tr_labels_list = [], []
        for rgb, flow, labels in train_loader:
            rgb, flow, labels = rgb.to(device), flow.to(device), labels.to(device)
            loss, logits = model_tta(rgb, flow, labels=labels)
            optimizer_t.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(trainable_t, max_norm=1.0)
            optimizer_t.step()
            tr_preds.extend(logits.argmax(1).cpu().numpy())
            tr_labels_list.extend(labels.cpu().numpy())
        scheduler_t.step()
        tr_f1 = f1_score(tr_labels_list, tr_preds, average='macro', zero_division=0)
        print(f"  Epoch {epoch:2d} | Train F1: {tr_f1:.3f} | {time.time()-t0:.1f}s")

    # eval with TTA
    te_preds, te_labels_list = [], []
    for video_path, start, end, label, key in test_ds.clips:
        pred = predict_with_tta(model_tta, video_path,
                                 start, end, key, device)
        te_preds.append(pred)
        te_labels_list.append(label)

    te_f1 = f1_score(te_labels_list, te_preds,
                      average='macro', zero_division=0)
    tta_results[user] = te_f1
    print(f"  TTA F1: {te_f1:.3f}")

print("STAGE 5b RESULTS — LOUO + TTA")
print("="*50)
for user, f1 in tta_results.items():
    print(f"  User {user}: TTA F1 = {f1:.3f}")
mean_tta = sum(tta_results.values()) / len(tta_results)
print(f"\n  Mean TTA F1: {mean_tta:.3f}")
# Out:
# Stage 5b — Test Time Augmentation
# ==================================================
# Re-evaluating each fold with 3-offset TTA
# ==================================================
#
# ==================================================
# Fold: hold out User B | test=['B001', 'B002', 'B003', 'B004', 'B005']
# ==================================================
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005']: 102 clips
# Suturing ['C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 691 clips
#   Train: 691 clips | Test: 102 clips
#   Epoch  1 | Train F1: 0.263 | 109.4s
#   Epoch  2 | Train F1: 0.596 | 110.2s
#   Epoch  3 | Train F1: 0.758 | 112.0s
#   Epoch  4 | Train F1: 0.764 | 112.5s
#   Epoch  5 | Train F1: 0.832 | 108.3s
#   Epoch  6 | Train F1: 0.840 | 108.1s
#   Epoch  7 | Train F1: 0.869 | 108.4s
#   Epoch  8 | Train F1: 0.871 | 108.7s
#   Epoch  9 | Train F1: 0.974 | 108.7s
#   Epoch 10 | Train F1: 0.978 | 108.7s
#   Epoch 11 | Train F1: 0.996 | 109.0s
#   Epoch 12 | Train F1: 0.996 | 108.5s
#   Epoch 13 | Train F1: 0.998 | 109.3s
#   Epoch 14 | Train F1: 0.998 | 109.3s
#   Epoch 15 | Train F1: 0.998 | 109.7s
#   TTA F1: 0.716
#
# ==================================================
# Fold: hold out User C | test=['C001', 'C002', 'C003', 'C004', 'C005']
# ==================================================
# Suturing ['C001', 'C002', 'C003', 'C004', 'C005']: 96 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 697 clips
#   Train: 697 clips | Test: 96 clips
#   Epoch  1 | Train F1: 0.217 | 115.1s
#   Epoch  2 | Train F1: 0.578 | 116.2s
#   Epoch  3 | Train F1: 0.723 | 117.6s
#   Epoch  4 | Train F1: 0.753 | 119.0s
#   Epoch  5 | Train F1: 0.806 | 120.7s
#   Epoch  6 | Train F1: 0.838 | 118.9s
#   Epoch  7 | Train F1: 0.863 | 119.7s
#   Epoch  8 | Train F1: 0.945 | 123.0s
#   Epoch  9 | Train F1: 0.986 | 123.7s
#   Epoch 10 | Train F1: 0.995 | 123.8s
#   Epoch 11 | Train F1: 0.994 | 123.2s
#   Epoch 12 | Train F1: 0.998 | 122.8s
#   Epoch 13 | Train F1: 0.999 | 121.5s
#   Epoch 14 | Train F1: 1.000 | 121.4s
#   Epoch 15 | Train F1: 0.999 | 121.3s
#   TTA F1: 0.873
#
# ==================================================
# Fold: hold out User D | test=['D001', 'D002', 'D003', 'D004', 'D005']
# ==================================================
# Suturing ['D001', 'D002', 'D003', 'D004', 'D005']: 114 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 679 clips
#   Train: 679 clips | Test: 114 clips
#   Epoch  1 | Train F1: 0.242 | 131.6s
#   Epoch  2 | Train F1: 0.592 | 135.1s
#   Epoch  3 | Train F1: 0.705 | 139.4s
#   Epoch  4 | Train F1: 0.734 | 138.5s
#   Epoch  5 | Train F1: 0.757 | 138.0s
#   Epoch  6 | Train F1: 0.790 | 137.9s
#   Epoch  7 | Train F1: 0.850 | 138.4s
#   Epoch  8 | Train F1: 0.926 | 139.5s
#   Epoch  9 | Train F1: 0.944 | 139.9s
#   Epoch 10 | Train F1: 0.982 | 139.7s
#   Epoch 11 | Train F1: 0.997 | 139.7s
#   Epoch 12 | Train F1: 0.999 | 139.2s
#   Epoch 13 | Train F1: 0.999 | 140.5s
#   Epoch 14 | Train F1: 0.999 | 139.7s
#   Epoch 15 | Train F1: 0.999 | 140.9s
#   TTA F1: 0.641
#
# ==================================================
# Fold: hold out User E | test=['E001', 'E002', 'E003', 'E004', 'E005']
# ==================================================
# Suturing ['E001', 'E002', 'E003', 'E004', 'E005']: 92 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 701 clips
#   Train: 701 clips | Test: 92 clips
#   Epoch  1 | Train F1: 0.286 | 144.6s
#   Epoch  2 | Train F1: 0.639 | 145.4s
#   Epoch  3 | Train F1: 0.782 | 146.5s
#   Epoch  4 | Train F1: 0.789 | 146.3s
#   Epoch  5 | Train F1: 0.809 | 148.2s
#   Epoch  6 | Train F1: 0.850 | 148.9s
#   Epoch  7 | Train F1: 0.852 | 151.9s
#   Epoch  8 | Train F1: 0.878 | 153.4s
#   Epoch  9 | Train F1: 0.967 | 151.5s
#   Epoch 10 | Train F1: 0.979 | 153.1s
#   Epoch 11 | Train F1: 0.998 | 150.3s
#   Epoch 12 | Train F1: 0.999 | 149.1s
#   Epoch 13 | Train F1: 0.998 | 148.2s
#   Epoch 14 | Train F1: 0.999 | 143.1s
#   Epoch 15 | Train F1: 0.999 | 143.9s
#   TTA F1: 0.657
#
# ==================================================
# Fold: hold out User F | test=['F001', 'F002', 'F003', 'F004', 'F005']
# ==================================================
# Suturing ['F001', 'F002', 'F003', 'F004', 'F005']: 90 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 703 clips
#   Train: 703 clips | Test: 90 clips
#   Epoch  1 | Train F1: 0.182 | 143.4s
#   Epoch  2 | Train F1: 0.654 | 139.2s
#   Epoch  3 | Train F1: 0.740 | 139.5s
#   Epoch  4 | Train F1: 0.773 | 148.2s
#   Epoch  5 | Train F1: 0.810 | 138.1s
#   Epoch  6 | Train F1: 0.845 | 139.6s
#   Epoch  7 | Train F1: 0.870 | 136.6s
#   Epoch  8 | Train F1: 0.875 | 113.8s
#   Epoch  9 | Train F1: 0.954 | 112.7s
#   Epoch 10 | Train F1: 0.959 | 112.8s
#   Epoch 11 | Train F1: 0.997 | 113.0s
#   Epoch 12 | Train F1: 0.982 | 113.8s
#   Epoch 13 | Train F1: 0.999 | 115.0s
#   Epoch 14 | Train F1: 0.999 | 115.4s
#   Epoch 15 | Train F1: 0.998 | 115.4s
#   TTA F1: 0.786
#
# ==================================================
# Fold: hold out User G | test=['G001', 'G002', 'G003', 'G004', 'G005']
# ==================================================
# Suturing ['G001', 'G002', 'G003', 'G004', 'G005']: 116 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'H001', 'H003', 'H004', 'H005', 'I001', 'I002', 'I003', 'I004', 'I005']: 677 clips
#   Train: 677 clips | Test: 116 clips
#   Epoch  1 | Train F1: 0.311 | 113.7s
#   Epoch  2 | Train F1: 0.649 | 112.3s
#   Epoch  3 | Train F1: 0.760 | 119.5s
#   Epoch  4 | Train F1: 0.831 | 123.7s
#   Epoch  5 | Train F1: 0.845 | 121.9s
#   Epoch  6 | Train F1: 0.844 | 120.9s
#   Epoch  7 | Train F1: 0.872 | 120.6s
#   Epoch  8 | Train F1: 0.894 | 120.7s
#   Epoch  9 | Train F1: 0.893 | 120.7s
#   Epoch 10 | Train F1: 0.947 | 121.0s
#   Epoch 11 | Train F1: 0.980 | 121.0s
#   Epoch 12 | Train F1: 0.998 | 120.9s
#   Epoch 13 | Train F1: 1.000 | 121.3s
#   Epoch 14 | Train F1: 1.000 | 120.9s
#   Epoch 15 | Train F1: 1.000 | 120.4s
#   TTA F1: 0.567
#
# ==================================================
# Fold: hold out User H | test=['H001', 'H003', 'H004', 'H005']
# ==================================================
# Suturing ['H001', 'H003', 'H004', 'H005']: 86 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'I001', 'I002', 'I003', 'I004', 'I005']: 707 clips
#   Train: 707 clips | Test: 86 clips
#   Epoch  1 | Train F1: 0.167 | 121.3s
#   Epoch  2 | Train F1: 0.613 | 121.3s
#   Epoch  3 | Train F1: 0.762 | 120.7s
#   Epoch  4 | Train F1: 0.815 | 120.7s
#   Epoch  5 | Train F1: 0.838 | 121.1s
#   Epoch  6 | Train F1: 0.852 | 121.2s
#   Epoch  7 | Train F1: 0.938 | 121.7s
#   Epoch  8 | Train F1: 0.885 | 121.6s
#   Epoch  9 | Train F1: 0.975 | 121.3s
#   Epoch 10 | Train F1: 0.994 | 121.3s
#   Epoch 11 | Train F1: 0.999 | 121.4s
#   Epoch 12 | Train F1: 0.999 | 121.1s
#   Epoch 13 | Train F1: 0.999 | 121.2s
#   Epoch 14 | Train F1: 0.999 | 121.2s
#   Epoch 15 | Train F1: 0.999 | 121.6s
#   TTA F1: 0.639
#
# ==================================================
# Fold: hold out User I | test=['I001', 'I002', 'I003', 'I004', 'I005']
# ==================================================
# Suturing ['I001', 'I002', 'I003', 'I004', 'I005']: 97 clips
# Suturing ['B001', 'B002', 'B003', 'B004', 'B005', 'C001', 'C002', 'C003', 'C004', 'C005', 'D001', 'D002', 'D003', 'D004', 'D005', 'E001', 'E002', 'E003', 'E004', 'E005', 'F001', 'F002', 'F003', 'F004', 'F005', 'G001', 'G002', 'G003', 'G004', 'G005', 'H001', 'H003', 'H004', 'H005']: 696 clips
#   Train: 696 clips | Test: 97 clips
#   Epoch  1 | Train F1: 0.267 | 115.6s
#   Epoch  2 | Train F1: 0.580 | 115.6s
#   Epoch  3 | Train F1: 0.751 | 115.4s
#   Epoch  4 | Train F1: 0.793 | 115.5s
#   Epoch  5 | Train F1: 0.829 | 115.4s
#   Epoch  6 | Train F1: 0.861 | 115.5s
#   Epoch  7 | Train F1: 0.864 | 116.0s
#   Epoch  8 | Train F1: 0.927 | 115.4s
#   Epoch  9 | Train F1: 0.886 | 115.3s
#   Epoch 10 | Train F1: 0.996 | 116.1s
#   Epoch 11 | Train F1: 0.997 | 115.2s
#   Epoch 12 | Train F1: 0.998 | 115.6s
#   Epoch 13 | Train F1: 0.998 | 114.9s
#   Epoch 14 | Train F1: 0.998 | 115.8s
#   Epoch 15 | Train F1: 0.998 | 115.7s
#   TTA F1: 0.799
# STAGE 5b RESULTS — LOUO + TTA
# ==================================================
#   User B: TTA F1 = 0.716
#   User C: TTA F1 = 0.873
#   User D: TTA F1 = 0.641
#   User E: TTA F1 = 0.657
#   User F: TTA F1 = 0.786
#   User G: TTA F1 = 0.567
#   User H: TTA F1 = 0.639
#   User I: TTA F1 = 0.799
#
#   Mean TTA F1: 0.710
